# %%
from google.colab import files
files.upload()
# !ls -lha kaggle.json
# !pip install -q kaggle # installing the kaggle package
# !mkdir -p ~/.kaggle # creating .kaggle folder where the key should be placed
# !cp kaggle.json ~/.kaggle/ # move the key to the folder
# !pwd # checking the present working directory
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# !kaggle datasets download -d "sartajbhuvaji/brain-tumor-classification-mri" -p "/content"
import os
os.mkdir("data")
# !unzip /content/brain-tumor-classification-mri.zip -d /content/data
# Out:
#      <input type="file" id="files-e50c9345-34d6-4d77-b0df-ee15e2a37b26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e50c9345-34d6-4d77-b0df-ee15e2a37b26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import Libraries
import tensorflow as tf
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, ReLU,
                                     Dropout, BatchNormalization, MaxPool2D)


from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential

from sklearn.preprocessing import StandardScaler,label_binarize
import numpy as np
import matplotlib.pyplot as plt
import cv2, joblib
import pandas as pd
import os
import random

from sklearn.metrics import classification_report, confusion_matrix , accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
import seaborn as sns

from tensorflow.keras import losses
from tensorflow.keras import backend as K
K.clear_session()


# ================================
# 1. Load and Preprocess Data
# ================================
DATASET_PATH = r"/content/data"

def load_data(dataset_path):
    images = []
    labels = []

    for label in os.listdir(dataset_path):
        label_path = os.path.join(dataset_path, label)
        if os.path.isdir(label_path):
            for img_file in os.listdir(label_path):
                img_path = os.path.join(label_path, img_file)
                img = cv2.imread(img_path) # Reading Images
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
                img = cv2.resize(img, (256, 256))  # Resize to 256x256
                images.append(img)
                labels.append(label)

    return np.array(images), np.array(labels)

# Load train and test data
train_images, train_labels = load_data(os.path.join(DATASET_PATH,"Training"))
test_images, test_labels = load_data(os.path.join(DATASET_PATH,"Testing"))
images = []
labels=[]

images.extend(train_images)
images.extend(test_images)
labels.extend(train_labels)
labels.extend(test_labels)

images = np.array(images)
labels = np.array(labels)
train_images,test_images,train_labels,test_labels =train_test_split(images,labels,test_size=0.2,random_state=10,shuffle=True)

# Normalize images

train_images = train_images / 255.0
test_images = test_images / 255.0

# Reshape to add channel dimension (since grayscale = 1 channel)
train_images = train_images.reshape(-1, 256, 256, 1)
test_images = test_images.reshape(-1, 256, 256, 1)


# Encode labels
encoder = LabelEncoder()
train_labels = encoder.fit_transform(train_labels)
test_labels = encoder.transform(test_labels)
classes = encoder.classes_
encoded = encoder.transform(classes)
classDict = dict(zip(encoded,classes))
print(classDict)

# Convert to categorical for softmax output
num_classes = len(np.unique(train_labels))
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# Shape
print(f"Train shape: {train_images.shape}, Test shape: {test_images.shape}")
print(f"Number of classes: {num_classes}")

# ================================
# 2. Create CNN Model
# ================================

def build_cnn(input_shape, num_classes):

    model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=input_shape),
    ReLU(),
    Conv2D(32, (3, 3), padding='same'),
    ReLU(),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), padding='same'),
    ReLU(),
    Conv2D(64, (3, 3), padding='same'),
    ReLU(),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), padding='same'),
    ReLU(),
    Conv2D(128, (3, 3), padding='same'),
    ReLU(),
    MaxPooling2D((2, 2)),

    Conv2D(256, (3, 3), padding='same'),
    ReLU(),

    MaxPooling2D((2, 2)),

    Conv2D(512, (3, 3), padding='same'),
    ReLU(),

    MaxPooling2D((2, 2)),

    Flatten(),

    Dense(256),
    ReLU(),

    Dropout(0.3),

    Dense(32),
    ReLU(),

    Dropout(0.4),

    Dense(4, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0007),
              loss= "categorical_crossentropy",
              metrics=['accuracy'])

    return model


# Build model
model = build_cnn((256, 256, 1), num_classes)
model.summary()


# ================================
# 4. Train the Model
# ================================
history = model.fit(
        train_images,train_labels,
        epochs=50,
        validation_data=(test_images,test_labels),
        verbose=1
    )

# ================================
# 5. Evaluate the Model
# ================================
loss, accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {accuracy * 100:.2f}%")
print(f"Test loss: {loss:.2f}")

# ================================
# 6. Plot Training Curves
# ================================
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')
plt.savefig(r'C:\Users\surya_hwzjtax\Desktop\datascience\BrainTumour\Models\acc_loss_graph.png')
plt.show()

# ================================
# 7. Save the Model
# ================================
model.save(r'C:\Users\surya_hwzjtax\Desktop\datascience\BrainTumour\Models\brain_tumor_cnn.h5')
print("Model saved as 'brain_tumor_cnn.h5'")
# Out:
# {np.int64(0): np.str_('glioma_tumor'), np.int64(1): np.str_('meningioma_tumor'), np.int64(2): np.str_('no_tumor'), np.int64(3): np.str_('pituitary_tumor')}
# Train shape: (2611, 256, 256, 1), Test shape: (653, 256, 256, 1)
# Number of classes: 4
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           320 │
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report
class_labels = ["Glioma Tumor","Meningioma Tumor","No Tumor","Pituitary Tumor"]
y_pred = model.predict(test_images)
pred_class = np.argmax(y_pred, axis=1)
true_class = np.argmax(test_labels, axis=1)
cm = confusion_matrix(true_class,pred_class)
print(cm)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# [[163  13   6   2]
#  [  4 164   3   5]
#  [  3   5  89   2]
#  [  0   0   0 194]]

# %%
# Classification Report
cr = classification_report(true_class,pred_class)
print("Classification Report\n",cr)
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       184
#            1       0.90      0.93      0.92       176
#            2       0.91      0.90      0.90        99
#            3       0.96      1.00      0.98       194
#
#     accuracy                           0.93       653
#    macro avg       0.93      0.93      0.93       653
# weighted avg       0.93      0.93      0.93       653

# %%
from sklearn.preprocessing import StandardScaler,label_binarize

# %%
# Validating Performance of the model
print(f"Test accuracy: {accuracy_score(true_class,pred_class) * 100:.2f}%")
print(f"Test f1 score: {f1_score(true_class,pred_class,average='weighted') * 100:.2f}%")
print(f"Test precision score: {precision_score(true_class,pred_class,average='weighted') * 100:.2f}%")
print(f"Test recall score: {recall_score(true_class,pred_class,average='weighted') * 100:.2f}%")
print(f"Test roc auc score: {roc_auc_score(true_class,label_binarize(pred_class, classes=np.arange(4)),average='macro', multi_class='ovr')* 100:.2f}%")
# Out:
# Test accuracy: 93.42%
# Test f1 score: 93.38%
# Test precision score: 93.46%
# Test recall score: 93.42%
# Test roc auc score: 95.35%

# %%
# Saving CNN Model to memory
model.save(r'content/brain_tumor_cnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
